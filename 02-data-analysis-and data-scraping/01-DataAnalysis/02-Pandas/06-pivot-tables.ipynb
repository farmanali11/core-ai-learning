# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Date": pd.date_range("2023-01-01", periods=20),
    "Product": ["A", "B", "C", "D"] * 5,
    "Region": [
        "East",
        "West",
        "North",
        "South",
        "East",
        "West",
        "North",
        "South",
        "East",
        "West",
        "North",
        "South",
        "East",
        "West",
        "North",
        "South",
        "East",
        "West",
        "North",
        "South",
    ],
    "Sales": np.random.randint(100, 1000, 20),
    "Units": np.random.randint(10, 100, 20),
    "Rep": [
        "John",
        "Mary",
        "Bob",
        "Alice",
        "John",
        "Mary",
        "Bob",
        "Alice",
        "John",
        "Mary",
        "Bob",
        "Alice",
        "John",
        "Mary",
        "Bob",
        "Alice",
        "John",
        "Mary",
        "Bob",
        "Alice",
    ],
}

df = pd.DataFrame(data)

df["Month"] = df["Date"].dt.month_name()
df["Quarter"] = "Q" + df["Date"].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    953     37   John  January      Q1
# 1  2023-01-02       B   West    123     55   Mary  January      Q1
# 2  2023-01-03       C  North    602     50    Bob  January      Q1
# 3  2023-01-04       D  South    962     18  Alice  January      Q1
# 4  2023-01-05       A   East    189     43   John  January      Q1
# 5  2023-01-06       B   West    841     83   Mary  January      Q1
# 6  2023-01-07       C  North    734     29    Bob  January      Q1
# 7  2023-01-08       D  South    950     34  Alice  January      Q1
# 8  2023-01-09       A   East    767     65   John  January      Q1
# 9  2023-01-10       B   West    589     19   Mary  January      Q1
# 10 2023-01-11       C  North    399     72    Bob  January      Q1
# 11 2023-01-12       D  South    452     40  Alice  January      Q1
# 12 2023-01-13       A   East    907     13   John  January      Q1
# 13 2023-01-14       B   West    156     32   Mary  January      Q1
# 14 2023-01-15       C  North    256     25    Bob  January      Q1
# 15 2023-01-16       D  South    228     38  Alice  January      Q1
# 16 2023-01-17       A   East    575     33   John  January      Q1
# 17 2023-01-18       B   West    342     99   Mary  January      Q1
# 18 2023-01-19       C  North    981     71    Bob  January      Q1
# 19 2023-01-20       D  South    263     49  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     767.0    NaN    NaN    NaN
# North      NaN    NaN  602.0    NaN
# South      NaN    NaN    NaN  452.0
# West       NaN  342.0    NaN    NaN

# %%
pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product')
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     678.2    NaN    NaN    NaN  38.2   NaN   NaN   NaN
# North      NaN    NaN  594.4    NaN   NaN   NaN  49.4   NaN
# South      NaN    NaN    NaN  571.0   NaN   NaN   NaN  35.8
# West       NaN  410.2    NaN    NaN   NaN  57.6   NaN   NaN
