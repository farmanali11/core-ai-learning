# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=[1,2,3,4,5]
y=[2,2,1,3,2]

plt.plot(x,y)

# plt.xticks(x)
# plt.yticks(x)

# plt.xlim(0,10)
# plt.ylim(0, 10)

plt.axis([0,10,0,8])

plt.show()
