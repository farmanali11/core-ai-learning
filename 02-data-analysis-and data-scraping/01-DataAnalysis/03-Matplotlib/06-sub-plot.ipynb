# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y= [1, 2, 3, 4, 5]

plt.subplot(2, 2, 1)
plt.plot(x,y,color='r')

plt.subplot(2, 2, 2)
plt.pie(x)

no = [
    32,
    16,
    48,
    22,
    24,
    53,
    15,
    55,
    49,
    47,
    45,
    55,
    21,
    37,
    36,
    37,
    34,
    52,
    29,
    47,
    32,
    56,
    39,
    51,
    53,
    56,
    27,
    55,
    45,
    43,
    27,
    39,
    14,
    50,
    45,
    35,
    54,
    49,
    44,
    17,
    10,
    23,
    17,
    14,
    19,
    20,
    29,
    49,
    29,
    30,
]

plt.subplot(2, 2, 3)
plt.hist(no)


x2=["a","s","d","f"]
y2=[2,3,2,3]
plt.subplot(2,2,4)
plt.bar(x2,y2)


plt.show()
