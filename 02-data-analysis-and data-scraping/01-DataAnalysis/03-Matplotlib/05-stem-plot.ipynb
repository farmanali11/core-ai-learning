# %% [markdown]
# # **Stem Plot Graph**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=[1,3,5,2,5,2]
y=[3,2,5,6,3,2]

plt.stem(x,y,linefmt=':',markerfmt='ro',basefmt='g',label='Python')

plt.legend()

plt.show()
