# %% [markdown]
# # HistoGram Graph

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x =np.random.randint(10,60,(50))
print(x)
# Out:
# [50 56 21 46 43 18 43 29 11 46 37 17 12 52 22 30 10 29 30 43 11 44 37 17
#  27 44 53 27 25 52 45 11 58 35 59 40 41 21 32 13 19 46 29 24 55 56 15 54
#  12 13]

# %%
no=[32,16 ,48 ,22 ,24 ,53 ,15 ,55 ,49 ,47 ,45 ,55 ,21 ,37 ,36 ,37 ,34, 52 ,29 ,47 ,32 ,56 ,39 ,51
 ,53 ,56 ,27 ,55 ,45 ,43 ,27 ,39 ,14 ,50 ,45 ,35 ,54 ,49 ,44 ,17 ,10 ,23 ,17 ,14 ,19 ,20 ,29 ,49
 ,29 ,30]

l = [10, 20, 30, 40, 50, 60]

plt.hist(no,color='b',edgecolor='k',bottom=20,rwidth=0.8)
plt.title("Data")
plt.xlabel("Python")

plt.axvline(45,color='g',label='Line')

plt.ylabel("No")
plt.legend()
plt.show()
