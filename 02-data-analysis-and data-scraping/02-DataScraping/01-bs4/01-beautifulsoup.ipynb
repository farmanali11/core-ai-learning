# %%
from bs4 import BeautifulSoup

with open ("index.html") as fp:
  soup = BeautifulSoup(fp,'html.parser')


  soup = BeautifulSoup("<html>a web page</html>", 'html.parser')

# %%
soup = BeautifulSoup('<b class="boldest">Extremely bold</b>', 'html.parser')
tag = soup.b
type(tag)
# Out:
# bs4.element.Tag

# %%
tag.name
# Out:
# 'b'

# %%
tag.name = "blackquote"

# %%
tag.name
# Out:
# 'blackquote'

# %%
tag
# Out:
# <blackquote class="boldest">Extremely bold</blackquote>

# %%
tag['id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tag['id']
#
# File c:\Users\farma\miniconda3\envs\ML\Lib\site-packages\bs4\element.py:2401, in Tag.__getitem__(self, key)
#    2398 def __getitem__(self, key: str) -> _AttributeValue:
#    2399     """tag[key] returns the value of the 'key' attribute for the Tag,
#    2400     and throws an exception if it's not there."""
# -> 2401     return self.attrs[key]
#
# KeyError: 'id'

# %%
tag.attrs
# Out:
# {'class': ['boldest']}

# %%
tag.attrs.key()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tag.attrs.key()
#
# AttributeError: 'AttributeDict' object has no attribute 'key'

# %%
tag['id'] = 'verybold'
tag['another attribute'] = 1

# %%
css_soup = BeautifulSoup('<p class="body"></p>', 'html.parser')
css_soup.p['class']
# Out:
# ['body']

# %%
css_soup = BeautifulSoup('<p class="body strikeout"></p>', 'html.parser')
css_soup.p['class']
# Out:
# ['body', 'strikeout']

# %%
with open('home.html', 'r', encoding='utf-8') as file:
    soup = BeautifulSoup(file.read(), 'lxml')

# %%
soup.find('head')
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" rel="stylesheet"/>
# <title>My Courses</title>
# </head>

# %%
soup.title
# Out:
# <title>My Courses</title>

# %%
soup.title.string
# Out:
# 'My Courses'

# %%
soup.p
# Out:
# <p class="card-text">If you are new to Python, this is the course that you should buy!</p>

# %%
soup.a
# Out:
# <a class="btn btn-primary" href="#">Start for 20$</a>

# %%
soup.find_all('a')
# Out:
# [<a class="btn btn-primary" href="#">Start for 20$</a>,
#  <a class="btn btn-primary" href="#">Start for 50$</a>,
#  <a class="btn btn-primary" href="#">Start for 100$</a>]

# %%
soup.find(id ="link3")

# %%
for link in soup.find_all('a'):
  print(link.get('href'))
# Out:
# #
# #
# #

# %%
print(soup.get_text())
# Out:
# My Courses
#
#
# Hello, Start Learning!
#
#
#             Python
#
#
# Python for beginners
# If you are new to Python, this is the course that you should buy!
# Start for 20$
#
#
#
#
#             Python
#
#
# Python Web Development
# If you feel enough confident with python, you are ready to learn how to create your own website!
# Start for 50$
#
#
#
#
#             Python
#
#
# Python Machine Learning
# Become a Python Machine Learning master!
# Start for 100$

# %%
head_tag = soup.head
head_tag
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" rel="stylesheet"/>
# <title>My Courses</title>
# </head>

# %%
head_tag.contents
# Out:
# ['\n',
#  <meta charset="utf-8"/>,
#  '\n',
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>,
#  '\n',
#  <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" rel="stylesheet"/>,
#  '\n',
#  <title>My Courses</title>,
#  '\n']

# %%
len(head_tag.contents)

title_tag = head_tag.contents[0]

# %%
title_tag.string
# Out:
# '\n'

# %%
head_tag.string

# %%
title_tag = soup.title

# %%
title_tag
# Out:
# <title>My Courses</title>

# %%
title_tag.parent
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.5.2/css/bootstrap.min.css" integrity="sha384-JcKb8q3iqJ61gNV9KGb8thSsNjpSL0n8PARn9HuZOnIxN0hoP+VmmDGMN5t9UJ0Z" rel="stylesheet"/>
# <title>My Courses</title>
# </head>

# %%
link = soup.a

# %%
link
# Out:
# <a class="btn btn-primary" href="#">Start for 20$</a>

# %%
for parent in link.parents:
  print(parent.name)
# Out:
# div
# div
# body
# html
# [document]

# %%
soup.find_all('b')
# Out:
# []

# %%
import re
for tag in soup.find_all(re.compile("^b")):
    print(tag.name)
# Out:
# body

# %%
for tag in soup.find_all(re.compile("t")):
    print(tag.name)
# Out:
# html
# meta
# meta
# title

# %%
soup.find_all(string="Elsie")
# Out:
# []

# %%
soup = BeautifulSoup("<a>Soup</a>",'html.parser')
soup.a.extend(["'s", " ", "on"])

soup
# Out:
# <a>Soup's on</a>

# %%
soup.a.contents
# Out:
# ['Soup', "'s", ' ', 'on']

# %%
markup = '<a href="http://example.com/">I linked to <i>example.com</i></a>'
soup = BeautifulSoup(markup,'html.parser')

tag = soup.a
new_string = tag.insert(1,"but ther is nothing like that")
tag.contents
# Out:
# ['I linked to ', 'but ther is nothing like that', <i>example.com</i>]

# %%
tag.clear()

# %%
tag
# Out:
# <a href="http://example.com/"></a>

# %%
markup = '<a href="http://example.com/">I linked to <i>example.com</i></a>'
soup = BeautifulSoup(markup,'html.parser')

a_tag = soup.a

i_tag = soup.i.extract()

a_tag
# Out:
# <a href="http://example.com/">I linked to </a>

# %%
i_tag
# Out:
# <i>example.com</i>

# %%
i_tag.contents
# Out:
# ['example.com']

# %%
soup = BeautifulSoup("<p>A one</p>", 'html.parser')
soup.p.append(", a two")


soup.p.contents
# Out:
# ['A one', ', a two']

# %%
print(soup.p.encode())
# Out:
# b'<p>A one, a two</p>'

# %%
print(soup.p.prettify())
# Out:
# <p>
#  A one
#  , a two
# </p>

# %%
soup.smooth()

# %%
soup.p.contents
# Out:
# ['A one, a two']

# %%
markup = '<html><head><body><a href="http://example.com/">I linked to <i>example.com</i></a>'

soup = BeautifulSoup(markup, 'html.parser')

soup.prettify()
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <body>
#    <a href="http://example.com/">
#     I linked to
#     <i>
#      example.com
#     </i>
#    </a>
#   </body>
#  </head>
# </html>

# %%
str(soup)
# Out:
# '<html><head><body><a href="http://example.com/">I linked to <i>example.com</i></a></body></head></html>'

# %%
str(soup.a)
# Out:
# '<a href="http://example.com/">I linked to <i>example.com</i></a>'

# %%
soup = BeautifulSoup("&ldquo;Dammit!&rdquo; he said.", 'html.parser')
str(soup)
# Out:
# '“Dammit!” he said.'

# %%
soup.encode("utf8")
# Out:
# b'\xe2\x80\x9cDammit!\xe2\x80\x9d he said.'

# %%
from bs4.formatter import HTMLFormatter

def uppercase(str):
  return str.upper()

formatter = HTMLFormatter(uppercase)


print(soup.prettify(formatter=formatter))
# Out:
# “DAMMIT!” HE SAID.
