# %%
import pdb
def add(a,b):
  return   a+b




pdb.set_trace()
# Out:
# --Call--
# > c:\users\farma\miniconda3\envs\ml\lib\site-packages\ipython\core\displayhook.py(269)__call__()
#     267         self._is_active = False
#     268
# --> 269     def __call__(self, result=None):
#     270         """Printing with history cache management.
#     271
#
# 34
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# *** SyntaxError: invalid syntax
# ...
