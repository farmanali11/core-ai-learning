# %% [markdown]
# 1. Python: Function that takes a sequence of numbers and determines whether all are different from each other

# %%
data = [int(x) for x in input("Enter a list of elements separated by commas: ").split(',')]

def Sequence(data):
    if len(data) == len(set(data)):
        return "All Elements in the List are Unique"
    else:
        return "List has Some Duplicate Elements"

print(Sequence([1,4,3,4,5]))
# Out:
# List has Some Duplicate Elements

# %% [markdown]
# 2. Create all possible strings by using a, e, i, o, u

# %%
import random 

strings = ['a','e','i','o','u']

random.shuffle(strings)
print(' '.join(strings))
# Out:
# i u a o e

# %% [markdown]
# 4. Find unique triplets whose three elements gives the sum of zero from an array of n integers

# %%
import collections

import pprint

file_input = input("Enter the File :")

with open(file_input, 'r') as info:

  count = collections.Counter(info.read().upper())

  value = pprint.pformat(count)
  print(value)

# %% [markdown]
# 8. Get the top stories from Google news

# %%
# %pip install beautifulsoup4
import bs4
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen

news_url = "https://news.google.com/news/rss"

Client = urlopen(news_url )

xml_page = Client.read()
Client.close()

soup_page = soup(xml_page, "xml")
news_list = soup_page.findAll("item")

for news in news_list:
    print(news.title.text)
    print(news.link.text)
    print(news.pubDate.text)
    print("-" * 60)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Solve using Dictionary
#
# ---

# %% [markdown]
# ## Problem 1: Concatenate Dictionaries
#
# Write a Python script to concatenate the following dictionaries to create a new one.
# ---

# %%
dict1 = {1:10, 2:20}
dict2 = {3:30, 4:40}
dict3 = {5:50, 6:60}

union = dict1 | dict2 | dict3
print(union)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# ## Problem 2: Merge Two Dictionaries
#
# Write a Python script to merge two Python dictionaries.
#
# ---

# %%
dict1 = {1:10, 2:20}
dict2 = {3:30, 4:40}
dict3 = {5:50, 6:60}

union = dict1 | dict2 | dict3
print(union)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %% [markdown]
# ## Problem 3: Combine Dictionaries by Adding Values for Common Keys
#
# Write a Python program to combine two dictionaries by adding values for common keys.
#
# **Given:**
#
# ```
# d1 = {'a': 100, 'b': 200, 'c': 300}
# d2 = {'a': 300, 'b': 200, 'd': 400}
# ```
#
# **Sample Output:**
#
# ```
# Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})
# ```
#
# ---

# %%
from collections import Counter
d1 = {'a': 100, 'b': 200, 'c': 300}
d2 = {'a': 300, 'b': 200, 'd': 400}

result = Counter(d1) + Counter(d2)
print(result)
# Out:
# Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})

# %% [markdown]
# ## Problem 4: Check if Multiple Keys Exist in a Dictionary
#
# Write a Python program to check if multiple keys exist in a dictionary.
#
# ---

# %%
d1 = {'name': 'Farman', 'age': 20, 'city': 'karachi'}

keys_to_check = ['name', 'age']

if d1.keys() >= set(keys_to_check):
    print("All keys are present in the dictionary.")
else:
    print("Some keys are missing from the dictionary.")
# Out:
# All keys are present in the dictionary.

# %% [markdown]
# ## Problem 5: Invert a Dictionary
#
# Write a Python program to invert a dictionary with unique hashable values.
#
# > Use `dictionary.items()` in combination with a **list comprehension** to create a new dictionary with the values and keys inverted.
#
# **Example Input:**
#
# ```
# students = {
#     'Theodore': 10,
#     'Mathew':   11,
#     'Roxanne':   9,
# }
# ```
#
# **Example Output:**
#
# ```
# {10: 'Theodore', 11: 'Mathew', 9: 'Roxanne'}
# ```

# %%
students = {
  'Theodore':10,
  'Mathew':11,
  'Roxanne':9,
}

inverted = {  value:key for key ,value in students.items()}
print(inverted)
# Out:
# {10: 'Theodore', 11: 'Mathew', 9: 'Roxanne'}

# %% [markdown]
# # Solve using Set
#
# ---

# %% [markdown]
# ## Problem 1: Remove Duplicates from a List of Strings
#
# Write a Python program to remove all duplicates from a given list of strings and return a list of unique strings.
#
# > Use the Python **set** data type.
#
# ---

# %%
l = input("Enter a List of the strings you want to remove duplicates").split(",")

print(set(l))
# Out:
# {'f', 'a', 'r', 'n', 'm'}

# %% [markdown]
# ## Problem 2: Find All Unique Combinations of 3 Numbers
#
# Write a Python program to find all the unique combinations of **3 numbers** from a given list of numbers that add up to a **target number**.
#
# ---

# %%
from itertools import combinations
n = [1,2,3]
result = list(combinations(n,3))

print(result)
# Out:
# [(1, 2, 3)]

# %% [markdown]
# ## Problem 3: Check if a Set is a Superset
#
# Write a Python program to check if a given set is:
#
# - A **superset of itself**
# - A **superset of another given set**
#
# ---

# %%
set = {1,2,3,4}

result = set.issuperset(set)

print(result)
# Out:
# True

# %% [markdown]
# ## Problem 4: Check if a Set is a Subset
#
# Write a Python program to check if a set is a **subset** of another set.
#
# ---

# %%
set = {1,2,3,4}

result = set.issubset(set)

print(result)
# Out:
# True

# %% [markdown]
# ## Problem 5: Add 3 Numbers Without `sum()` or `+` Operator
#
# Add 3 numbers together **without** using the `sum()` function or the `+` operator.
#
# > ⚠️ **Constraint:** You may **ONLY** use **Bitwise Operators** to solve this problem.

# %% [markdown]
# # Solve Using Tuples
#
# ---

# %% [markdown]
# ## Problem 1: Sort a Tuple by its Float Element
#
# Write a Python program to sort a tuple by its float element.
#
# **Sample Data:**
#
# ```
# [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
# ```
#
# **Expected Output:**
#
# ```
# [('item3', '24.5'), ('item2', '15.10'), ('item1', '12.20')]
# ```
#
# ---

# %%
price = [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]

sort = sorted(price, key=lambda f:float(f[1]),reverse=True)

print(sort)
# Out:
# [('item3', '24.5'), ('item2', '15.10'), ('item1', '12.20')]

# %% [markdown]
# ## Problem 2: Calculate the Product of All Numbers in a Tuple
#
# Write a Python program to calculate the product, multiplying all the numbers in a given tuple.
#
# **Example 1:**
#
# ```
# Original Tuple:
# (4, 3, 2, 2, -1, 18)
#
# Product - multiplying all the numbers of the said tuple: -864
# ```
#
# **Example 2:**
#
# ```
# Original Tuple:
# (2, 4, 8, 8, 3, 2, 9)
#
# Product - multiplying all the numbers of the said tuple: 27648
# ```
#
# ---

# %%
import math 
OriginalTuple = (4,3,2,2,-1,18)
result = math.prod(OriginalTuple)
print(result)
# Out:
# -864

# %% [markdown]
# ## Problem 3: Convert a Tuple of String Values to Integer Values
#
# Write a Python program to convert a tuple of string values to a tuple of integer values.
#
# **Original Tuple Values:**
#
# ```
# (('333', '33'), ('1416', '55'))
# ```
#
# **New Tuple Values:**
#
# ```
# ((333, 33), (1416, 55))
# ```
#
# ---

# %%
import builtins
t = ('333', '33', '1416', '55')
converted_tuple = builtins.tuple(int(x) for x in t)
print(converted_tuple)
# Out:
# (333, 33, 1416, 55)

# %% [markdown]
# ## Problem 4: Compute the Element-Wise Sum of Given Tuples
#
# Write a Python program to compute the element-wise sum of given tuples.
#
# **Original Tuples:**
#
# ```
# (1, 2, 3, 4)
# (3, 5, 2, 1)
# (2, 2, 3, 1)
# ```
#
# **Element-Wise Sum:**
#
# ```
# (6, 9, 8, 6)
# ```
#
# ---

# %%
import builtins

t = [(1, 2, 3, 4),(3, 5, 2, 1),(2, 2, 3, 1)]
answer = builtins.tuple(sum(x) for x in zip(*t))
print(answer)
# Out:
# (6, 9, 8, 6)

# %% [markdown]
# ## Problem 5: Convert a List of Tuples to a List of Lists
#
# Write a Python program to convert a given list of tuples to a list of lists.
#
# **Example 1:**
#
# ```
# Original list of tuples:
# [(1, 2), (2, 3), (3, 4)]
#
# Converted list of lists:
# [[1, 2], [2, 3], [3, 4]]
# ```
#
# **Example 2:**
#
# ```
# Original list of tuples:
# [(1, 2), (2, 3, 5), (3, 4), (2, 3, 4, 2)]
#
# Converted list of lists:
# [[1, 2], [2, 3, 5], [3, 4], [2, 3, 4, 2]]
# ```

# %%
t = [(1, 2), (2, 3), (3, 4)]
l = []
l = list(t)
print(type(l))
print(l)
# Out:
# <class 'list'>
# [(1, 2), (2, 3), (3, 4)]

# %% [markdown]
# # Solve Using List
#
# ---

# %% [markdown]
# ## Problem 1: Sort by Last Element of Each Tuple
#
# Write a Python program to get a list, sorted in increasing order by the last element in each tuple from a given list of non-empty tuples.
#
# **Sample List:**
#
# ```
# [(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]
# ```
#
# **Expected Result:**
#
# ```
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]
# ```
#
# ---

# %%
l = [(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]

result  = sorted(l, key=lambda x:x[-1])
print(result)
# Out:
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]

# %% [markdown]
# ## Problem 2: Clone or Copy a List
#
# Write a Python program to clone or copy a list.
#
# > ⚠️ **Constraint:** You may **NOT** use `copy()` or `deepcopy()`.
#
# ---

# %%
l = [10,12,14,15]
clone = list(l)
print(clone)
# Out:
# [10, 12, 14, 15]

# %% [markdown]
# ## Problem 3: Check if All Numbers in a List are Prime
#
# Write a Python program to check if each number is prime in a given list of numbers.
#
# > Return `True` if **all** numbers are prime, otherwise return `False`.
#
# **Sample Data:**
#
# ```
# ([0, 3, 4, 7, 9])  -> False
# ([3, 5, 7, 13])    -> True
# ([1, 5, 3])        -> False
# ```
#
# ---

# %%
def prime(n):
  if(n==1):
    return False
  elif(n==2):
    return False
  else:
    for i in range(2,n):
      if(n%2 == 1):
        return False
    return True

# %% [markdown]
# ## Problem 4: Create a List by Concatenating with a Range
#
# Write a Python program to create a list by concatenating a given list with a range from `1` to `n`.
#
# **Sample List:**
#
# ```
# ['p', 'q']
# ```
#
# **n = 5**
#
# **Sample Output:**
#
# ```
# ['p1', 'q1', 'p2', 'q2', 'p3', 'q3', 'p4', 'q4', 'p5', 'q5']
# ```
#
# ---

# %%
myList= [1,2]
myrange = (1,11)

result = myList+ list(range(3,10))
print(result)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ## Problem 5: Remove Key-Value Pairs from a List of Dictionaries
#
# Write a Python program to remove key-value pairs from a list of dictionaries.
#
# ---

# %%
data = [
  {'name':'Farman','age':'22','city':'Karachi'},
  
  {'name':'Ali','age':'22','city':'Lahore'}
]

for x in data:
  x.pop('age',None)


print(data)
# Out:
# [{'name': 'Farman', 'city': 'Karachi'}, {'name': 'Ali', 'city': 'Lahore'}]

# %% [markdown]
# ## Problem 6: Extend a List Without Using `append()`
#
# Write a Python program to extend a list without appending.
#
# **Sample Data:**
#
# ```
# [10, 20, 30]
# [40, 50, 60]
# ```
#
# **Expected Output:**
#
# ```
# [40, 50, 60, 10, 20, 30]
# ```

# %%
myList = [10,20,30]

myList.extend([40,50,60])

print(myList)
# Out:
# [10, 20, 30, 40, 50, 60]
