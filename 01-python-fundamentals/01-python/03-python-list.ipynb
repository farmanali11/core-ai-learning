# %%
L1 = ['Apple','Banana','Cherry']
L2 = ["Orange","Mango","Grapes"]

L3 = L1 + L2 

print(L3)
# Out:
# ['Apple', 'Banana', 'Cherry', 'Orange', 'Mango', 'Grapes']

# %%
L1 = [1,2,3,4]
total = 1

for i in L1:
  total = total*i

print(total)
# Out:
# 24

# %%
def smallest(L):
  min = L[0]

  for i in L:
    if i < min:
      min = i

    return min

smallest([1,2,3,4,10])
# Out:
# 1

# %%
del max

# %%
L =[1,2,3,4,5]

print(max((L)))
# Out:
# 5

# %%
L = [1, 2, 3, 4, 5, 23]

def Largest(L):
  b =L[0]

  for i in L:
    if i > b:
       b = i
  return b

print(Largest(L))
# Out:
# 23

# %%
L = [1, 0, 3, 4, 5, 23]

def Smallest(L):
  b =L[0]

  for i in L:
    if i < b:
       b = i
  return b

print(Smallest(L))
# Out:
# 0

# %%
L = [1, 2, 0, 4, 5, 23]
print(min(L))
# Out:
# 0

# %%
L = [(2, 5  ), (1, 2), (4, 4), (2, 3), (2, 1)]


def last(n):
  return n[-1]

def sort_list_last(L):
  return sorted(L,key = last)

print(sort_list_last([(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]))
# Out:
# [(2, 1), (1, 2), (2, 3), (4, 4), (2, 5)]

# %%
L = ['a','b','c','a']
L1 = set(L)
print(L1)
# Out:
# {'b', 'a', 'c'}

# %%
class BankAccount:
  def __init__(self,owner,balance):
    self.owner = owner
    self.balance = balance

    def depost(self,amount):
     if amount > 0:
       self.balance = amount + balance
       

    def withdraw(self,amount):
      if amount <=0:
        print("Amount must be greater than 0 ")
      elif: 
      amount > self.balance:
      




d = BankAccount('Farman',400)
print(d.depos))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 18
#      14
#      15
#      16
#      17 d = BankAccount('Farman',400)
# ---> 18 print(d.deposit(300))
#
# AttributeError: 'BankAccount' object has no attribute 'deposit'

# %%
class Animal:
  def __init__(self,name,sound):
    self.name = name
    self.sound = sound
  def Speak(self):
    return f"{self.name} says {self.sound}"

class Dog(Animal):
    def __init__(self, name):
      super().__init__(name,"Bark")
class Cat(Animal):
    def __init__(self, name):
      super().__init__(name,"Meow")


my_dog = Dog("Buddy")
my_cat = Cat("Kaa")
print(my_dog.Speak())


print(my_cat.Speak())
# Out:
# Buddy says Bark
# Kaa says Meow

# %%
class Book:
  def __init__(self,title,author,year):
    self.title = title
    self.author = author
    self.year = year
class Library:
  def __init__(self,name):
    self.name = name
    self.books = []
  def add_book(self,book):
    self.append(book)
    print(f"{self.book} added...")
  def remove_book(self,book):
    self.remove(book)
    print(f"{book} is removed... ")
  def search_by_author(self):
    [b for b in self.books  if self.author]
  def list_all_books(self):
