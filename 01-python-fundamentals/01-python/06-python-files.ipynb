# %%
f = open("file.txt")
print(f"cursor position is {f.tell()}")
print(f.read())
print(f"cursor position is {f.tell()}")
f.close()
# Out:
# cursor position is 0
# Hi there this is me Farman ALi a swe graduate and Transitioning myself towards the AI Engineering...
# Regards
# cursor position is 110

# %%
f = open("file.txt")

print(f.readline( ))
# Out:
# Hi there this is me Farman ALi a swe graduate and Transitioning myself towards the AI Engineering...

# %%
print(f.name)
# Out:
# file.txt

# %%
print(f.closed)
# Out:
# False

# %%
with open('file.txt') as f:
  data = f.read()

  print(data)
# Out:
# Hi there this is me Farman ALi a swe graduate and Transitioning myself towards the AI Engineering...
# Regards

# %%
with open("file.txt","r+") as f:
  f.seek(len(f.read()))
  data = f.write("Please do it my dear friend...")

# %%
with open("file1.txt",'r') as rf:
  with open("file.txt",'w') as wf:
    wf.write(rf.read())

# %%
from csv import reader

with open("file.csv","r") as f:
  csv_reader = reader(f)
  next(csv_reader)

  for row in csv_reader:
    print(row)
# Out:
# ['farman', 'farmanali@gmail.com', '030000']
# ['ali', 'ali@gmail.com', '03023']
# ['baloch', 'baloch@gmail.com', '03040']

# %%
from csv import DictReader

with open("file.csv","r") as f:
  csv_reader  = DictReader(f)

  for row in csv_reader:
    print(row["email"])
# Out:
# farmanali@gmail.com
# ali@gmail.com
# baloch@gmail.com

# %%
from csv import DictWriter

with open("file.csv","w") as f:
  csv_writer = DictWriter(f,fieldnames=["firstname","lastname","age"])
  csv_writer.writeheader()

# %%
csv_writer.writerow({
  "firstname":"Farman",
  "lastname":"Ali",
  "age":"22"
})


csv_writer.writerow({
  "firstname":"arman",
  "lastname":"li",
  "age":"20"
})


csv_writer.writerow({
  "firstname":"rman",
  "lastname":"i",
  "age":"24"
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 csv_writer.writerow({
#       2   "firstname":"Farman",
#       3   "lastname":"Ali",
#       4   "age":"22"
#
# File c:\Users\farma\miniconda3\envs\ML\Lib\csv.py:154, in DictWriter.writerow(self, rowdict)
#     153 def writerow(self, rowdict):
# --> 154     return self.writer.writerow(self._dict_to_list(rowdict))
#
# ValueError: I/O operation on closed file.
