# %%
import os 
print(os.getcwd())
# Out:
# c:\Farman\03_Arsenal\01_Launchpad\ML-Practice

# %%
if os.path.exists('movies'):
  print("File already exists")
else:
  os.mkdir('movies')
# Out:
# File already exists

# %%
print(os.listdir())
# Out:
# ['assess.ipynb', 'chapter17errors.ipynb', 'exercise.ipynb', 'file.csv', 'file.txt', 'file1.txt', 'files.ipynb', 'first.ipynb', 'movies', 'ObjectOrientedP.ipynb', 'OS.ipynb', 'p.ipynb', 'practice.ipynb']

# %%
import os 
shutil.rmtree('songs')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 import os
# ----> 2 shutil.rmtree('songs')
#
# NameError: name 'shutil' is not defined
