# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('forecasting-dataset.csv')

# %%
df.head()
# Out:
#    postcode Day_of_Week      Date               Branch Name  Total Sale  \
# 0  KA21 5DT    Saturday  2/1/2025  galos peri peri hamilton      347.53
# 1  KA21 5DT      Sunday  2/2/2025  galos peri peri hamilton      119.68
# 2  KA21 5DT      Monday  2/3/2025  galos peri peri hamilton      136.20
# 3  KA21 5DT     Tuesday  2/4/2025  galos peri peri hamilton       92.67
# 4  KA21 5DT   Wednesday  2/5/2025  galos peri peri hamilton      124.94
#
#   outercode  population  households  avg_household_income  unemployment_rate  \
# 0      KA21         686         548            13716.9812               0.43
# 1      KA21         686         548            13716.9812               0.43
# 2      KA21         686         548            13716.9812               0.43
# 3      KA21         686         548            13716.9812               0.43
# 4      KA21         686         548            13716.9812               0.43
#
# ...

# %% [markdown]
# ## 1.Scatterplot (Numrical-Numercial)

# %%
sns.scatterplot(x='Total Sale', y='Total_Sale_Normalized', data=df,hue='unemployment_rate', palette='viridis')
# Out:
# <Axes: xlabel='Total Sale', ylabel='Total_Sale_Normalized'>

# %% [markdown]
# ## 2. Barplot (Numerical - Categorical)

# %%
sns.barplot(x="Day_of_Week", y="Total_Sale_Normalized", data=df)
# Out:
# <Axes: xlabel='Day_of_Week', ylabel='Total_Sale_Normalized'>

# %% [markdown]
# ## 3. Boxplot (Numerical - Categorical)

# %% [markdown]
# ## 4. Distplot (Numerical - Categorical)
